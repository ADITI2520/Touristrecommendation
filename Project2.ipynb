# %%
import pandas as pd
df=pd.read_csv("Book1.csv")
print(df.to_string())
# Out:
#     Id                        Names          State        Type BestTimeToVisit  Popularity Region
# 0    1                    Taj Mahal  Uttar Pradesh  Historical         Nov-Feb    8.691906  North
# 1    2                  Jaipur City      Rajasthan        City         Oct-Mar    8.605032  North
# 2    3                       Kerela         Kerela      Nature         Sep-Mar    9.225372  South
# 3    4                       Ladakh  Jammu Kashmir   Adventure         Apr-Jun    7.977386  South
# 4    5                          Goa    Maharashtra     Beaches         Apr-Jun    8.399822   West
# 5    6                      Gujarat    Maharashtra     Beaches         Nov-Feb    7.648950   West
# 6    7                        Bihar          Bihar      Temple         Sep-Mar    8.691906   East
# 7    8                    Agra Fort  Uttar Pradesh  Historical         Sep-Mar    8.605032  North
# 8    9                  Jhansi Fort  Uttar Pradesh  Historical        Nov-Feb     9.225372  North
# ...

# %%
## import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv("Book1.csv")
#print(df.to_string())


i=pd.Series(df["Id"])
d=pd.Series(df["Names"])
s=pd.Series(df["State"])
t=pd.Series(df["Type"])
b=pd.Series(df["BestTimeToVisit"])
x=pd.Series(df["Region"])


#-------------------------------------------STATE-------------------------------------------------------------------
lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["State"]=="Uttar Pradesh":
        lst.append(i)
s1=df.loc[lst]
p=s1.sort_values(by=["Popularity"],ascending=False)

lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["State"]=="Rajasthan":
        lst.append(i)
s2=df.loc[lst]
p1=s2.sort_values(by=["Popularity"],ascending=False)


lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["State"]=="Kerela":
        lst.append(i)
s3=df.loc[lst]
p2=s3.sort_values(by=["Popularity"],ascending=False)

lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["State"]=="Delhi":
        lst.append(i)
s4=df.loc[lst]
p3=s4.sort_values(by=["Popularity"],ascending=False)

lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["State"]=="Maharashtra":
        lst.append(i)
s5=df.loc[lst]
p4=s5.sort_values(by=["Popularity"],ascending=False)


lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["State"]=="Karnatak":
        lst.append(i)
s6=df.loc[lst]
p5=s6.sort_values(by=["Popularity"],ascending=False)


lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["State"]=="Bihar":
        lst.append(i)
s7=df.loc[lst]
p6=s7.sort_values(by=["Popularity"],ascending=False)



#---------------------------------------------------TYPE------------------------------------------------------------------
lst1=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["Type"]=="Historical":
        lst1.append(i)
d0=df.loc[lst1]
pop0=d0.sort_values(by=["Popularity"],ascending=False)

lst1=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["Type"]=="Beaches":
        lst1.append(i)
d1=df.loc[lst1]
pop1=d1.sort_values(by=["Popularity"],ascending=False)


lst1=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["Type"]=="Park":
        lst1.append(i)
d2=df.loc[lst1]
pop2=d2.sort_values(by=["Popularity"],ascending=False)

lst1=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["Type"]=="Adventure":
        lst1.append(i)
d3=df.loc[lst1]
pop3=d3.sort_values(by=["Popularity"],ascending=False)

lst1=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["Type"]=="Temple":
        lst1.append(i)
d4=df.loc[lst1]
pop4=d4.sort_values(by=["Popularity"],ascending=False)

lst1=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["Type"]=="WaterFall":
        lst1.append(i)
d5=df.loc[lst1]
pop5=d5.sort_values(by=["Popularity"],ascending=False)

lst1=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["Type"]=="Nature":
        lst1.append(i)
d6=df.loc[lst1]
pop6=d6.sort_values(by=["Popularity"],ascending=False)

lst1=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["Type"]=="City":
        lst1.append(i)
d7=df.loc[lst1]
pop7=d7.sort_values(by=["Popularity"],ascending=False)



#------------------------------------------------------------------BEST TIME TO VISIT--------------------------------------------------
lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["BestTimeToVisit"]=="Nov-Feb":
        lst.append(i)
b1=df.loc[lst]

lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["BestTimeToVisit"]=="Oct-Mar":
        lst.append(i)
b2=df.loc[lst]

lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["BestTimeToVisit"]=="Sep-Mar":
        lst.append(i)
b3=df.loc[lst]

lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["BestTimeToVisit"]=="Apr-Jun":
        lst.append(i)
b4=df.loc[lst]



lst=[]
for i in range(0,len(df)):
    d=df.loc[i]
    if d["BestTimeToVisit"]=="Jun-Sep":
        lst.append(i)
b5=df.loc[lst]





#---------------------------------------------------------------LOOP---------------------------------------------------------------
while True:
    print("ENTER CHOICE")
    n1=int(input("1=>Select State\n2=>Select The Type\n3=>Select The Month You Want To Visit\n4=>Exist\n"))
    print(" ")
#------------------------------------------------STATE LOOP-------------------------------------------------------------------------
    if n1==1:
        while True:
                print("YOU CAN SELECT PLACE AS PER STATE\n")           
                user=int(input("1=>Uttar Pradesh\n2=>Kerela\n3=>Karnatak\n4=>Maharashtra\n5=>Delhi\n6=>Bihar\n7=>Rajasthan\n8=>Exist\n"))
            
                if user==1:
                    print("LIST OF PLACES TO VISIT IN UTTAR PRADESH\n \n",s1,"\n \n")
                    x=p["Names"]
                    y=p["Popularity"]
                    plt.bar(x,y,width=0.5,color="Green")
                    plt.xlabel("Places")
                    plt.ylabel("Popularity")
                    plt.show()
                    print("\n \n")
                   #--------------------------REGION LOOP----------------------------------
                    n=int(input("1=>Enter 1 for Recommendation\n2=>Exit\n"))
                    if n==1:                        
                        lst=[]
                        for i in range(0,len(df)):
                            d=df.loc[i]
                            if d["Region"]=="North" and d["State"]!="Uttar Pradesh":
                                lst.append(i)
                        r=df.loc[lst]
                        print(r)
                    elif n==2:
                        break
                    x=r["State"]
                    y=r["Popularity"]
                    #l=r["Names"]
                    plt.bar(x,y,width=0.5,color="Black")
                    plt.xlabel("State")
                    plt.ylabel('Popularity')
                    plt.show()
                        
                    '''   
                    lst1=[]
                    #print(lst)
                    for i in range(0,len(r)):
                        d=r.loc[i]
                        if d["State"]=="Uttar Pradesh":
                                lst1.append(i)
                    b4=r.loc[lst1]
                    print(b4)
                    '''                 
                            
                elif user==2:
                    print("LIST OF PLACES TO VISIT IN KERELA\n \n",s3,"\n \n")
                    x=p2["Names"]
                    y=p2["Popularity"]
                    plt.bar(x,y,width=0.5,color="Pink")
                    plt.xlabel("Places")
                    plt.ylabel("Popularity")
                    plt.show()
                    print("\n \n")
                    #--------------------------REGION LOOP----------------------------------
                    n=int(input("1=>Type 1 For More Recommendation\n2=>Exist\n"))
                    if n==1:
                        lst=[]
                        for i in range(0,len(df)):
                            d=df.loc[i]
                            if d["Region"]=="South" and d["State"]!="Kerela":
                                lst.append(i)
                        r1=df.loc[lst]
                        print(r1)
                    elif n==2:
                        break
                    x=r1["State"]
                    y=r1["Popularity"]
                    plt.bar(x,y,width=0.5,color="Black")
                    plt.xlabel("State")
                    plt.ylabel("Popularity")
                    plt.show()

                elif user==3:
                    print("LIST OF PLACES TO VISIT IN KARNATAK\n \n",s6,"\n \n")
                    x=p5["Names"]
                    y=p5["Popularity"]
                    plt.bar(x,y,width=0.5,color="Purple")
                    plt.xlabel("Places")
                    plt.ylabel("Popularity")
                    plt.show()
                    #--------------------------REGION LOOP----------------------------------
                    n=int(input("Enter 1 for Recommendation\n2=>Exist\n"))
                    if n==1:                       
                        lst=[]
                        for i in range(0,len(df)):
                            d=df.loc[i]
                            if d["Region"]=="South" and d["State"]!="Karnatak":
                                lst.append(i)
                        r1=df.loc[lst]
                        print(r1)
                    elif n==2:
                        break                    
                    print("\n \n")
                    
                elif user==4:
                    print("LIST OF PLACES TO VISIT IN MAHARASHTRA\n \n",s5,"\n \n")
                    x=p4["Names"]
                    y=p4["Popularity"]
                    plt.bar(x,y,width=0.5,color="Blue")
                    plt.xlabel("Places")
                    plt.ylabel("Popularity")
                    plt.show()
                    #--------------------------REGION LOOP----------------------------------
                    n=int(input("Enter 1 for Recommendation\n2=>Exist\n"))
                    if n==1:                      
                        lst=[]
                        for i in range(0,len(df)):
                            d=df.loc[i]
                            if d["Region"]=="West" and d["State"]!="Maharashtra":
                                lst.append(i)
                        r2=df.loc[lst]
                        print(r2)
                    elif n==2:
                        break
                    x=r2["State"]
                    y=r2["Popularity"]
                    plt.bar(x,y,width=0.5,color="Black")
                    plt.xlabel("State")
                    plt.ylabel("Popularity")
                    plt.show()
                        
                elif user==5:
                    print("LIST OF PLACES TO VISIT IN DELHI\n \n",s4,"\n \n")
                    x=p3["Names"]
                    y=p3["Popularity"]
                    plt.bar(x,y,width=0.5,color="Yellow")
                    plt.xlabel("Places")
                    plt.ylabel("Popularity")
                    plt.show()
                    #--------------------------REGION LOOP----------------------------------
                    n=int(input("1=>Enter 1 for Recommendation\n2=>Exit\n"))
                    if n==1:                        
                        lst=[]
                        for i in range(0,len(df)):
                            d=df.loc[i]
                            if d["Region"]=="North" and d["State"]!="Delhi":
                                lst.append(i)
                        r=df.loc[lst]
                        print(r)
                    elif n==2:
                        break
                    x=r["State"]
                    y=r["Popularity"]
                    plt.bar(x,y,width=0.5,color="Black")
                    plt.xlabel("State")
                    plt.ylabel("Popularity")
                    plt.show()
                        
                elif user==6:
                    print("LIST OF PLACES TO VISIT BIHAR\n \n",s7,"\n \n")
                    x=p6["Names"]
                    y=p6["Popularity"]
                    plt.bar(x,y,width=0.5,color="HotPink")
                    plt.xlabel("Places")
                    plt.ylabel("Popularity")
                    plt.show()
                    #--------------------------REGION LOOP----------------------------------
                    n=int(input("1=>Enter 1 for Recommendation\n2=>Exist\n")) 
                    if n==1:                        
                        lst=[]
                        for i in range(0,len(df)):
                            d=df.loc[i]
                            if d["Region"]=="East" and d["State"]!="Bihar":
                                lst.append(i)
                        r3=df.loc[lst]
                        print(r3)
                    elif n==2:
                        break 
                    x=r3["State"]
                    y=r3["Popularity"]
                    plt.bar(x,y,width=0.5,color="Black")
                    plt.xlabel("State")
                    plt.ylabel("Popularity")
                    plt.show()
                    print("\n \n")
                    
                elif user==7:
                    print("LIST OF PLACES TO VISIT IN RAJASTHAN\n \n",s2,"\n \n")
                    x=p1["Names"]
                    y=p1["Popularity"]
                    plt.bar(x,y,width=0.5,color="Orange")
                    plt.xlabel("Places")
                    plt.ylabel("Popularity")
                    plt.show()
                    #--------------------------REGION LOOP----------------------------------
                    n=int(input("1=>Enter 1 for Recommendation\n2=>Exit\n"))
                    if n==1:                        
                        lst=[]
                        for i in range(0,len(df)):
                            d=df.loc[i]
                            if d["Region"]=="North" and d["State"]!="Rajasthan":
                                lst.append(i)
                        r=df.loc[lst]
                        print(r)
                    elif n==2:
                        break
                    x=r["State"]
                    y=r["Popularity"]
                    plt.bar(x,y,width=0.5,color="Black")
                    plt.xlabel("State")
                    plt.ylabel("Popularity")
                    plt.show()
                    print("\n \n")
                    
                elif user==8:
                    break
#----------------------------------------------------TYPE LOOP-------------------------------------------------------------------
    if n1==2:
                while True:
                    print("YOU CAN SELECT TYPE YOU WANT TO VISIT\n")
                    user1=int(input("1=>Historical\n2=>Beaches\n3=>Park\n4=>Adventure\n5=>Temple\n6=>WaterFall\n7=>Nature\n8=>City\n9=>Exist\n"))
                    if user1==1:
                        print("LIST OF HISTORICAL PLACES\n \n ",d0,"\n \n")
                        x=pop0["State"]
                        y=pop0["Popularity"]
                        plt.bar(x,y,width=0.5,color="Purple")
                        plt.xlabel("State")
                        plt.ylabel("Popularity")
                        plt.title("State Vise Popularity")
                        plt.show()
                    elif user1==2:
                        print("LiIST OF BEACHES PLACES\n \n",d1,"\n \n")
                        x=pop1["State"]
                        y=pop1["Popularity"]
                        plt.bar(x,y,width=0.5,color="Purple")
                        plt.xlabel("State")
                        plt.ylabel("Popularity")
                        plt.title("State Vise Popularity")
                        plt.show()
                    elif user1==3:
                        print("LIST OF PARK PLACES\n \n",d2,"\n \n")
                        x=pop2["State"]
                        y=pop2["Popularity"]
                        plt.bar(x,y,width=0.5,color="Purple")
                        plt.xlabel("State")
                        plt.ylabel("Popularity")
                        plt.title("State Vise Popularity")
                        plt.show()
                    elif user1==4:
                        print("LIST OF ADVENTURE PLACES\n \n",d3,"\n \n")
                        x=pop3["State"]
                        y=pop3["Popularity"]
                        plt.bar(x,y,width=0.5,color="Purple")
                        plt.xlabel("State")
                        plt.ylabel("Popularity")
                        plt.title("State Vise Popularity")
                        plt.show()
                    elif user1==5:
                        print("LIST OF TEMPLE PLACES\n \n",d4,"\n \n")
                        x=pop4["State"]
                        y=pop4["Popularity"]
                        plt.bar(x,y,width=0.5,color="Purple")
                        plt.xlabel("State")
                        plt.ylabel("Popularity")
                        plt.title("State Vise Popularity")
                        plt.show()
                    elif user1==6:
                        print("LIST OF WATERFALL PLACES\n \n",d5,"\n \n")
                        x=pop5["State"]
                        y=pop5["Popularity"]
                        plt.bar(x,y,width=0.5,color="Purple")
                        plt.xlabel("State")
                        plt.ylabel("Popularity")
                        plt.title("State Vise Popularity")
                        plt.show()
                    elif user1==7:
                        print("LIST OF NATURE PLACES\n \n",d6,"\n \n")
                        x=pop6["State"]
                        y=pop6["Popularity"]
    
                        plt.bar(x,y,width=0.5,color="Purple")
                        plt.xlabel("State")
                        plt.ylabel("Popularity")
                        plt.title("State Vise Popularity")
                        plt.show()
                    elif user1==8:
                        print("LIST OF CITY PLACES\n \n",d7,"\n \n")
                        x=pop7["State"]
                        y=pop7["Popularity"]
                        plt.bar(x,y,width=0.5,color="Purple")
                        plt.xlabel("State")
                        plt.ylabel("Popularity")
                        plt.title("State Vise Popularity")
                        plt.show()
                    elif user1==9:
                        break
#---------------------------------------------------BEST TIME TO VISIT LOOP-----------------------------------------------------
    elif n1==3:
        while True:
            print("YOU CAN SELECT THE MONTH YOU WANT TO VISIT\n")
            user1=int(input("1=>Nov-Feb\n2=>Oct-Mar\n3=>Sep-Mar\n4=>Apr-Jun\n5=>Jun-Sep\n6=>Exist\n"))
            if user1==1:
                print("LIST OF PLACES TO VISIT IN NOV-FEB\n",b1,"\n \n")
            elif user1==2:
                print("LIST OF PLACES TO VISIT IN OCT-MAR\n",b2,"\n \n")
            elif user1==3:
                print("LIST OF PLACES TO VISIT IN SEP-MAR\n",b3,"\n \n")
            elif user1==4:
                print("LSIT OF PLACES TO VISIT IN APR-JUN\n",b4,"\n \n")
            elif user1==5:
                print("LIST OF PLACES TO VISIT IN JUN-SEP\n",b5,"\n \n")
            elif user1==6:
                break
                                
    elif n1==4:
        print("THANK YOU HAVE A SAFE JOURNEY")
        break
# Out:
# ENTER CHOICE
# 1=>Select State
# 2=>Select The Type
# 3=>Select The Month You Want To Visit
# 4=>Exist
#  1
#
# YOU CAN SELECT PLACE AS PER STATE
# 1=>Uttar Pradesh
# 2=>Kerela
# 3=>Karnatak
# 4=>Maharashtra
# 5=>Delhi
# 6=>Bihar
# 7=>Rajasthan
# 8=>Exist
#  1
# LIST OF PLACES TO VISIT IN UTTAR PRADESH
#
#      Id        Names          State        Type BestTimeToVisit  Popularity  \
# 0    1    Taj Mahal  Uttar Pradesh  Historical         Nov-Feb    8.691906
# 7    8    Agra Fort  Uttar Pradesh  Historical         Sep-Mar    8.605032
# 8    9  Jhansi Fort  Uttar Pradesh  Historical        Nov-Feb     9.225372
# 10  11      Ayodhya  Uttar Pradesh      Temple         Nov-Feb    8.399822
#
#    Region
# 0   North
# 7   North
# 8   North
# 10  North
# 1=>Enter 1 for Recommendation
# 2=>Exit
#  1
#     Id           Names      State        Type BestTimeToVisit  Popularity  \
# 1    2     Jaipur City  Rajasthan        City         Oct-Mar    8.605032
# ...
